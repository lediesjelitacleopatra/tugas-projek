# %%
# buat variabel skalar x dan simpan suatu nilai skalar

x = 80
x
# Out:
# 80

# %%
# tampilkan tipe data dari x
type(x)
# Out:
# int

# %%
# buat variabel skalar y dan simpan suatu nilai skalar
y = 80

# %%
# tampilkan tipe data dari y
type(y)
# Out:
# int

# %%
# jumlahkan x+y
py_sum = x + y
py_sum
# Out:
# 160

# %%
# buat variabel bernama x_float dan simpan suatu nilai desimal
x_float = 0,80

# %%
# jumlahkan x_float dengan y
x_float = 0.80
float_sum = x_float + y
float_sum
# Out:
# 80.8

# %%
# tampilkan tipe data dari x_float
type(x_float)
# Out:
# float

# %% [markdown]
# 2. lakukan tahapan pada soal 1 dengan menggunakan tensorflow

# %%
import tensorflow as tf

# %%
#  buat variabel skalar x dan simpan suatu nilai skalar
x_tf = 80

# %%
# tampilkan tipe data dari x
type(x_tf)
# Out:
# int

# %%
# buat variabel skalar y dan simpan suatu nilai skalar
y_tf = 80

# %%
# tampilkan tipe data dari y
type(y_tf)
# Out:
# int

# %%
# jumlahkan x+y
x_tf + y_tf
# Out:
# 160

# %%
# buat variabel bernama x_float dan simpan suatu nilai desimal
tf_float = 0.80
tf_float
# Out:
# 0.8

# %%
# jumlahkan x_float dengan y
tf_float + y_tf
# Out:
# 80.8

# %%
# tampilkan tipe data dari x_float
type(tf_float)
# Out:
# float

# %% [markdown]
# 3. lakukan tahapan pada soal 1 dengan menggunakan pytorch

# %%
import torch

# %%
# buat variabel skalar x dan simpan suatu nilai skalar
x_pt = torch.tensor(80) # type specification optional, e.g.: dtype=torch.float16
x_pt
# Out:
# tensor(80)

# %%
# tampilkan tipe data dari x
type(x_pt)
# Out:
# torch.Tensor

# %%
# buat variabel skalar y dan simpan suatu nilai skalar
y_pt = torch.tensor(80)
y_pt
# Out:
# tensor(80)

# %%
# tampilkan tipe data dari y
type(y_pt)
# Out:
# torch.Tensor

# %%
# jumlahkan x+y
y_pt + x_pt
# Out:
# tensor(160)

# %%
# buat variabel bernama x_float dan simpan suatu nilai desimal
x_float_pt = torch.tensor(0.80)
x_float_pt
# Out:
# tensor(0.8000)

# %%
# jumlahkan x_float dengan y
x_float_pt + y_pt
# Out:
# tensor(80.8000)

# %%
# tampilkan tipe data dari x_float
type(x_float_pt)
# Out:
# torch.Tensor
