# %%
import numpy as np

# %%
# buat vector i dengan elemen (1,0) dan vector j dengan elemen (0,1)
i = np.array([1, 0])
j = np.array([0, 1])

# %%
print("Vector i:", i)
print("Vector j:", j)
# Out:
# Vector i: [1 0]
# Vector j: [0 1]

# %%
# Cek orthogonal (dot product)
dot_ij = np.dot(i, j)
print("\nDot product i · j =", dot_ij)
# Out:
# Dot product i · j = 0

# %%
if dot_ij == 0:
    print("Vector i dan j ORTHOGONAL")
else:
    print("Vector i dan j TIDAK orthogonal")
# Out:
# Vector i dan j ORTHOGONAL

# %%
# Cek apakah orthonormal (panjang = 1)
norm_i = np.linalg.norm(i)
norm_j = np.linalg.norm(j)

# %%
print("\nPanjang i:", norm_i)
print("Panjang j:", norm_j)

if norm_i == 1 and norm_j == 1:
    print("Vector i dan j ORTHONORMAL")
# Out:
# Panjang i: 1.0
# Panjang j: 1.0
# Vector i dan j ORTHONORMAL

# %%
# 2. Vector v dan w
v = np.array([1, 2])
w = np.array([2, -1])

# %%
print("\nVector v:", v)
print("Vector w:", w)
# Out:
# Vector v: [1 2]
# Vector w: [ 2 -1]

# %%
# Cek orthogonal
dot_vw = np.dot(v, w)
print("\nDot product v · w =", dot_vw)

if dot_vw == 0:
    print("Vector v dan w ORTHOGONAL")
else:
    print("Vector v dan w TIDAK orthogonal")
# Out:
# Dot product v · w = 0
# Vector v dan w ORTHOGONAL
